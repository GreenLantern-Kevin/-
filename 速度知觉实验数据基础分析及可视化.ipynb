# %%
# 导入Python的数据处理库pandas，相当于python里的excel
import pandas as pd

# 导入python高级数据可视化库seaborn
import seaborn as sns

# 导入python绘图matplotlib
import matplotlib.pyplot as plt

# 使用ipython的魔法方法，将绘制出的图像直接嵌入在notebook单元格中
# %matplotlib inline

# 设置绘图大小
plt.style.use({'figure.figsize':(25,20)})

plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %% [markdown]
# # 安全人机工程学速度知觉实验数据

# %% [markdown]
# 本数据搜集自本班部分同学的相关实验数据。
# 其中包括性别、速度模式、差别阀限、反馈情况四个变量。

# %% [markdown]
# # 导入数据集

# %% [markdown]
# ## 从外部csv文件导入（csv文件是逗号分隔文件，在数据分析中常用此格式）

# %%
df_minedisease = pd.read_csv('速度知觉实验数据精简.csv',encoding='utf-8')

# %%
df_minedisease.head()  # 输出前五行数据
# Out:
#    性别  速度模式  差别阀限（s）  反馈情况
# 0   1     1     0.33     1
# 1   1     1     0.32     2
# 2   1     1     0.12     1
# 3   1     2     0.62     1
# 4   1     2     0.22     2

# %%
df_minedisease.shape  # 查看数据格式，16行10列
# Out:
# (54, 4)

# %% [markdown]
# # 数据探索性分析（EDA）

# %% [markdown]
# ## 探索数据结构

# %%
df_minedisease.head() # 用.head方法可以看到前五行数据
# Out:
#    性别  速度模式  差别阀限（s）  反馈情况
# 0   1     1     0.33     1
# 1   1     1     0.32     2
# 2   1     1     0.12     1
# 3   1     2     0.62     1
# 4   1     2     0.22     2

# %%
df_minedisease.shape  # .shape 查看数据结构
# Out:
# (54, 4)

# %%
df_minedisease.dtypes # .dtypes 查看数据类型
# Out:
# 性别           int64
# 速度模式         int64
# 差别阀限（s）    float64
# 反馈情况         int64
# dtype: object

# %%
df_minedisease.info() # .info查看有没有缺失值
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   性别       54 non-null     int64
#  1   速度模式     54 non-null     int64
#  2   差别阀限（s）  54 non-null     float64
#  3   反馈情况     54 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 1.8 KB

# %%
df_minedisease.isnull().any().sum()
# Out:
# 0

# %%
df_minedisease.describe() # .describe 得到每一列数据的统计特征
# Out:
#               性别       速度模式    差别阀限（s）       反馈情况
# count  54.000000  54.000000  54.000000  54.000000
# mean    1.333333   1.555556   0.402963   1.333333
# std     0.475831   0.501570   0.240264   0.475831
# min     1.000000   1.000000   0.120000   1.000000
# 25%     1.000000   1.000000   0.232500   1.000000
# 50%     1.000000   2.000000   0.325000   1.000000
# 75%     2.000000   2.000000   0.550000   2.000000
# max     2.000000   2.000000   1.160000   2.000000

# %%
df_minedisease.corr() # .corr得到各变量两两之间的皮尔逊相关性系数
# Out:
#                    性别          速度模式   差别阀限（s）          反馈情况
# 性别       1.000000e+00 -7.905694e-02  0.060514 -2.775558e-17
# 速度模式    -7.905694e-02  1.000000e+00 -0.106292  1.755417e-17
# 差别阀限（s）  6.051370e-02 -1.062924e-01  1.000000 -4.362488e-01
# 反馈情况    -2.775558e-17  1.755417e-17 -0.436249  1.000000e+00

# %% [markdown]
# ## 数据可视化

# %%
# 设置绘图大小，长15高10
plt.style.use({'figure.figsize':(15,10)})

# %%
df_minedisease.hist(bins=15) # 分15个区段
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4F967DD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4F99CF080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4F9A011D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4F9A30320>]],
#       dtype=object)

# %%
# 绘制变量之间两两关系的散点图，绘制这个图可能要花一分钟左右
sns.pairplot(df_minedisease)

# %%
df_minedisease.plot() # 画出所有变量的折线图

# %%
df_minedisease.plot(subplots=True,figsize=(20,45))
plt.show() # 把每个单独的画出来

# %%
df_minedisease.plot(kind='hist',bins=15) # 用柱状图把每个单独的表示出来

# %%
sns.boxplot(data=df_minedisease[['性别','速度模式','差别阀限（s）','反馈情况']])
plt.title('速度知觉实验数据集，一些特征的箱型图')
# Out:
# Text(0.5, 1.0, '速度知觉实验数据集，一些特征的箱型图')

# %%
sns.violinplot(data=df_minedisease[['性别','速度模式','差别阀限（s）','反馈情况']])
plt.title('速度知觉实验数据集，一些特征的小提琴图') # 可以很容易看到峰值
# Out:
# Text(0.5, 1.0, '速度知觉实验数据集，一些特征的小提琴图')

# %%
sns.distplot(df_minedisease['性别']) # 既可以画出直方图，又可以画出概率密度曲线

# %%
sns.distplot(df_minedisease['速度模式'])

# %%
sns.distplot(df_minedisease['差别阀限（s）'])

# %%
sns.distplot(df_minedisease['反馈情况'])

# %%
# 绘制变量间相关性系数热力图
sns.heatmap(df_minedisease.corr(),square=True,annot=True,cmap='YlGnBu')

# %% [markdown]
# ## 把某一个特征和差别阀限的散点图画出来

# %%
# 设置绘图大小
plt.style.use({'figure.figsize':(10,8)})

# %%
df_minedisease.columns
# Out:
# Index(['性别', '速度模式', '差别阀限（s）', '反馈情况'], dtype='object')

# %%
for each in df_minedisease.columns:
    plt.scatter(df_minedisease[each],df_minedisease['差别阀限（s）'])
    plt.title(' {} 与差别阀限散点图'.format(each))
    plt.xlabel(each)
    plt.ylabel('差别阀限（s）')
    plt.yticks(range(0,5,1))
    plt.grid()
    plt.show()

# %% [markdown]
# # 特征选择

# %% [markdown]
# 使用与目标变量的相关性强的变量作为最终的特征变量。
#
# 通过相关系数法进行特征选择

# %%
df_minedisease.head()
# Out:
#    性别  速度模式  差别阀限（s）  反馈情况
# 0   1     1     0.33     1
# 1   1     1     0.32     2
# 2   1     1     0.12     1
# 3   1     2     0.62     1
# 4   1     2     0.22     2

# %%
# 构造训数据集的特征,把标签这一列删掉
drop_columns = ['性别']
x = df_minedisease.drop(drop_columns, axis=1)

# %%
x.head()
# Out:
#    速度模式  差别阀限（s）  反馈情况
# 0     1     0.33     1
# 1     1     0.32     2
# 2     1     0.12     1
# 3     2     0.62     1
# 4     2     0.22     2

# %%
y = df_minedisease['差别阀限（s）']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
SelectKBest = SelectKBest(f_regression, k=3)
bestFeature = SelectKBest.fit_transform(x,y)
SelectKBest.get_support()
x.columns[SelectKBest.get_support()]  # 选出三个特征
# Out:
# Index(['速度模式', '差别阀限（s）', '反馈情况'], dtype='object')
